# %% [markdown]
# # Twin Delayed Deep Deterministic policy gradient algorithm (TD3)
#
# TD3 builds on the Deep Deterministic Policy Gradient algorithm (DDPG)
#
# ### 1. Import the Necessary Packages

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import gym
import random
import pickle
import seaborn as sns
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

from tensorboardX import SummaryWriter
from unityagents import UnityEnvironment
from agents.td3_agent import Agent
from agents.utils.RunConfig import RunConfig
from agents.utils.buffers import Experience

# %%
def get_env(seed):
    from sys import platform as _platform
    if _platform == "linux" or _platform == "linux2":
       # linux
        env = UnityEnvironment(file_name="../unity_envs/Reacher_Linux/Reacher.x86_64", seed=seed)
    elif _platform == "darwin":
       # MAC OS X
       env = UnityEnvironment(file_name="../unity_envs/Reacher.app", no_graphics = False, seed=seed)
    return env

def get_train_env_multi(seed):
    from sys import platform as _platform
    if _platform == "linux" or _platform == "linux2":
       # linux
        env = UnityEnvironment(file_name="../unity_envs/Reacher_Linux_Multi/Reacher.x86_64", seed=seed)
    elif _platform == "darwin":
       # MAC OS X
       env = UnityEnvironment(file_name="../unity_envs/Reacher_Multi.app", no_graphics = False, seed=seed)
    return env

def welcome(seed, multi = True):
    if multi:
        env = get_train_env_multi(seed)
    else:
        env = get_env(seed)

    # get the default brain
    brain_name = env.brain_names[0]
    brain = env.brains[brain_name]

    # reset the environment
    env_info = env.reset(train_mode=True)[brain_name]

    # number of agents
    num_agents = len(env_info.agents)

    # size of each action
    action_size = brain.vector_action_space_size

    # examine the state space
    states = env_info.vector_observations
    state_size = states.shape[1]
    print('Number of agents:', num_agents)
    print('Size of each action:', action_size)
    print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))

    return env, state_size, action_size, num_agents

# %%
def plot_data(data, title, color = 'b'):
    fig = plt.figure()
    sns.tsplot(data, color=color)
    plt.xlabel('Episode', fontsize=16)
    plt.ylabel('Avg. Episodic Return', fontsize=20)
    plt.title(title, fontsize=30)
    plt.show()

def plot_scores(data):
    train_scores = []
    eval_scores = []
    for k, v in data.items():
        train_score_i = v[0]
        eval_scores_i = v[1]
        train_score_i = np.mean(np.array(train_score_i), axis=1).tolist()
        eval_scores_i = np.mean(np.array(eval_scores_i), axis=1).tolist()
        train_scores.append(train_score_i)
        eval_scores.append(eval_scores_i)

    plot_data(train_scores, 'Train Scores', color='b')
    plot_data(train_scores, 'Eval Scores', color='r')

# %%
def save_model(agent, dir, prefix=''):
    import os
    if not os.path.exists(dir + prefix):
        os.makedirs(dir + prefix)

    torch.save(agent.actor_local.state_dict(),
               dir + prefix + 'actor.pth')
    torch.save(agent.critics_local[0].state_dict(),
               dir + prefix + 'critic_0.pth')
    torch.save(agent.critics_local[1].state_dict(),
               dir + prefix + 'critic_1.pth')
    
    return tuple([dir + prefix + net_name for net_name in ['critic_0.pth', 'critic_1.pth', 'actor.pth']])

# %% [markdown]
# ### Simulation

# %%
def eval_td3(env, config):
    agent = config.eval_agent

    brain_name = env.brain_names[0]
    env_info = env.reset(train_mode=True)[brain_name]  # reset the environment
    s = env_info.vector_observations  # get the current state (for each train_agent)
    num_agents = len(env_info.agents)
    G = np.zeros(num_agents)  # Undiscounted return for each train_agent

    t = 0
    while True:
        a = agent.act(s, add_noise = False)               # select an action from train_agent
        env_info = env.step(a)[brain_name]                # send all actions to tne environment
        sp = env_info.vector_observations                 # get next state (for each train_agent)
        rewards = np.array(env_info.rewards)              # get reward (for each train_agent)
        dones = np.array(env_info.local_done)             # see if episode finished
        G += rewards                                      # update the score (for each train_agent)
        if np.any(dones):                                 # exit loop if episode finished
            break
        else:
            s = sp                                # roll over states to next time step
            t += 1
    return G

# %%
def td3_train(env, config, n_episodes=2000, max_t=int(10000), prefix='', algo = 'td3'):
    scores_deque = deque(maxlen=100)
    undisc_G = []
    undisc_eval_G = []
    agent = config.train_agent
    episode_horizons = deque(maxlen=100)
    brain_name = env.brain_names[0]
    env_solved = False
    best_score = 0.

    for i_episode in range( n_episodes):
        env_info = env.reset(train_mode=True)[brain_name]
        s = env_info.vector_observations
        n_agents = s.shape[0]
        agent.reset()
        score = np.zeros((n_agents, 1), dtype=np.float32)
        for t in range(max_t):
            a = agent.act(s)
            env_info = env.step(a)[brain_name]
            sp = env_info.vector_observations
            r = np.array(env_info.rewards)[..., None]
            done = np.array(env_info.local_done)[..., None]
            if t+1 == max_t:
                done = np.ones_like(done, dtype = np.bool)

            agent.step(Experience(s=s, a=a, r=r, sp=sp, done=done.astype(np.float32)))
            s = sp
            score += r
            if np.all(done):
                episode_horizons.append(t)
                break

        scores_deque.append(score)
        undisc_G.append(score)
        writer.add_scalar('score_G', np.mean(score), i_episode)
        print('\rEpisode {}\tAverage Score: {:.2f}\tScore: {:.2f}'.format(i_episode, np.mean(scores_deque), float(np.mean(score))), end="")

        if i_episode % 50 == 0:
            print('')

        if (np.mean(scores_deque) >= 30.) and (i_episode > 99) and (not env_solved):
            print('\n 100-avg score of 30 reached in {} episodes\n'.format(i_episode))
            env_solved = True

        if best_score < float(np.mean(undisc_G[i_episode])):
            best_score = np.mean(undisc_G[i_episode])
            print('\t- Mean episodic undiscounted return improved. Saving model - ')
            critic_0_path, critic_1_path, actor_path = save_model(agent, dir='../models/{}/'.format(algo), prefix=prefix)
            config.critic_0_log_dir = critic_0_path
            config.critic_1_log_dir = critic_1_path
            config.actor_log_dir = actor_path

        if (i_episode + 1) % config.eval_interval == 0:
            eval_G=eval_td3(env, config)
            print('\tEval mean return: {:.2f}'.format(np.mean(eval_G)))
            undisc_eval_G.append(eval_G)

    return undisc_G, undisc_eval_G

# %% [markdown]
# ##### Parameters

# %%
n_episodes = 1000
rollout = 1000
seed = 30

# %%
config = RunConfig()
config.batch_size = 512
config.replay_buffer_size = 1e6
config.rollout = rollout
config.discount = 0.99
config.eval_interval = 10
config.eval_episodes = 1
config.actor_grad_clip = None
config.critic_grad_clip = 1.
config.exploratory_sigma_start = 0.2
config.exploratory_sigma_end = 0.2
config.exploration_steps = int(1e3)
config.sigma_decay_steps = int(1e6)
config.update_actor_interval = 2
config.actor_lr = 1e-3
config.critic_lr = 1e-3
config.tau_pi = 5e-3
config.tau_q = 5e-3

# %%
env_name = 'reacher'
prefix = 'reacher/'
algo = 'td3'
log_dir = '../logs/{}/'.format(algo) + env_name + '/'
pickl_name = 'scores.pkl'

if not os.path.isdir(log_dir):
    os.makedirs(log_dir)

env, state_size, action_size, n_agents = welcome(seed)
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_size -> 5.0
# 		goal_speed -> 1.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33

# %% [markdown]
# ### Train the Agent
#
# Run the code cell below to train the agent from scratch.

# %%
writer = SummaryWriter(log_dir='../logs/{}/'.format(algo) + prefix)
agent = Agent(state_size=state_size,
                    action_size=action_size,
                    random_seed=seed,
                    n_agents=n_agents,
                    writer=writer,
                    config=config)

config.train_agent = agent
config.eval_agent = agent

# %%
undisc_G, undisc_eval_G = td3_train(env, config, max_t = config.rollout, 
                                    prefix=prefix, n_episodes=n_episodes, 
                                    algo=algo)
env.close()
# Out:
# Episode 0	Average Score: 0.03	Score: 0.03
# 	- Mean episodic undiscounted return improved. Saving model -
# Episode 1	Average Score: 0.48	Score: 0.94	- Mean episodic undiscounted return improved. Saving model -
# Episode 3	Average Score: 0.71	Score: 0.95	- Mean episodic undiscounted return improved. Saving model -
# Episode 5	Average Score: 0.80	Score: 1.09	- Mean episodic undiscounted return improved. Saving model -
# Episode 8	Average Score: 0.91	Score: 1.29	- Mean episodic undiscounted return improved. Saving model -
# Episode 9	Average Score: 0.99	Score: 1.71	- Mean episodic undiscounted return improved. Saving model -
# 	Eval mean return: 1.43
# Episode 10	Average Score: 1.08	Score: 2.01	- Mean episodic undiscounted return improved. Saving model -
# Episode 11	Average Score: 1.29	Score: 3.62	- Mean episodic undiscounted return improved. Saving model -
# Episode 12	Average Score: 1.54	Score: 4.42	- Mean episodic undiscounted return improved. Saving model -
# Episode 13	Average Score: 1.82	Score: 5.49	- Mean episodic undiscounted return improved. Saving model -
# Episode 14	Average Score: 2.10	Score: 6.05	- Mean episodic undiscounted return improved. Saving model -
# Episode 15	Average Score: 2.41	Score: 7.01	- Mean episodic undiscounted return improved. Saving model -
# Episode 16	Average Score: 2.69	Score: 7.22	- Mean episodic undiscounted return improved. Saving model -
# Episode 17	Average Score: 3.09	Score: 9.93	- Mean episodic undiscounted return improved. Saving model -
# Episode 19	Average Score: 3.79	Score: 10.52	- Mean episodic undiscounted return improved. Saving model -
# 	Eval mean return: 11.02
# Episode 20	Average Score: 4.13	Score: 10.90	- Mean episodic undiscounted return improved. Saving model -
# Episode 22	Average Score: 4.83	Score: 13.65	- Mean episodic undiscounted return improved. Saving model -
# Episode 23	Average Score: 5.22	Score: 14.26	- Mean episodic undiscounted return improved. Saving model -
# Episode 24	Average Score: 5.59	Score: 14.34	- Mean episodic undiscounted return improved. Saving model -
# Episode 25	Average Score: 6.00	Score: 16.38	- Mean episodic undiscounted return improved. Saving model -
# Episode 26	Average Score: 6.43	Score: 17.46	- Mean episodic undiscounted return improved. Saving model -
# Episode 27	Average Score: 6.84	Score: 18.03	- Mean episodic undiscounted return improved. Saving model -
# Episode 28	Average Score: 7.27	Score: 19.37	- Mean episodic undiscounted return improved. Saving model -
# Episode 29	Average Score: 7.76	Score: 21.93	- Mean episodic undiscounted return improved. Saving model -
# 	Eval mean return: 20.15
# Episode 30	Average Score: 8.24	Score: 22.43	- Mean episodic undiscounted return improved. Saving model -
# Episode 31	Average Score: 8.68	Score: 22.56	- Mean episodic undiscounted return improved. Saving model -
# Episode 33	Average Score: 9.50	Score: 23.85	- Mean episodic undiscounted return improved. Saving model -
# Episode 34	Average Score: 10.00	Score: 26.87	- Mean episodic undiscounted return improved. Saving model -
# Episode 35	Average Score: 10.48	Score: 27.54	- Mean episodic undiscounted return improved. Saving model -
# Episode 39	Average Score: 12.12	Score: 27.38	Eval mean return: 26.45
# Episode 41	Average Score: 12.88	Score: 29.11	- Mean episodic undiscounted return improved. Saving model -
# Episode 42	Average Score: 13.26	Score: 29.14	- Mean episodic undiscounted return improved. Saving model -
# Episode 44	Average Score: 13.95	Score: 29.36	- Mean episodic undiscounted return improved. Saving model -
# Episode 45	Average Score: 14.31	Score: 30.71	- Mean episodic undiscounted return improved. Saving model -
# Episode 46	Average Score: 14.69	Score: 32.11	- Mean episodic undiscounted return improved. Saving model -
# Episode 49	Average Score: 15.65	Score: 31.57	Eval mean return: 28.37
# Episode 50	Average Score: 15.97	Score: 32.18
# 	- Mean episodic undiscounted return improved. Saving model -
# Episode 52	Average Score: 16.59	Score: 32.47	- Mean episodic undiscounted return improved. Saving model -
# Episode 53	Average Score: 16.89	Score: 32.54	- Mean episodic undiscounted return improved. Saving model -
# Episode 57	Average Score: 17.92	Score: 32.82	- Mean episodic undiscounted return improved. Saving model -
# Episode 58	Average Score: 18.18	Score: 33.31	- Mean episodic undiscounted return improved. Saving model -
# Episode 59	Average Score: 18.45	Score: 34.06	- Mean episodic undiscounted return improved. Saving model -
# 	Eval mean return: 34.71
# Episode 60	Average Score: 18.72	Score: 35.36	- Mean episodic undiscounted return improved. Saving model -
# Episode 62	Average Score: 19.26	Score: 37.11	- Mean episodic undiscounted return improved. Saving model -
# Episode 68	Average Score: 20.75	Score: 37.49	- Mean episodic undiscounted return improved. Saving model -
# Episode 69	Average Score: 20.97	Score: 35.87	Eval mean return: 36.67
# Episode 79	Average Score: 22.83	Score: 36.85	Eval mean return: 38.36
# Episode 89	Average Score: 24.37	Score: 37.48	Eval mean return: 38.44
# Episode 90	Average Score: 24.51	Score: 37.59	- Mean episodic undiscounted return improved. Saving model -
# Episode 96	Average Score: 25.28	Score: 38.47	- Mean episodic undiscounted return improved. Saving model -
# Episode 99	Average Score: 25.60	Score: 35.58	Eval mean return: 35.32
# Episode 100	Average Score: 25.95	Score: 35.29
# Episode 109	Average Score: 29.02	Score: 35.04	Eval mean return: 35.51
# Episode 113	Average Score: 30.26	Score: 35.15
#  100-avg score of 30 reached in 113 episodes
#
# Episode 119	Average Score: 31.82	Score: 34.18	Eval mean return: 34.37
# Episode 129	Average Score: 33.64	Score: 34.59	Eval mean return: 35.85
# Episode 139	Average Score: 34.54	Score: 32.70	Eval mean return: 31.02
# Episode 149	Average Score: 34.99	Score: 33.06	Eval mean return: 31.36
# Episode 150	Average Score: 35.01	Score: 33.55
# Episode 159	Average Score: 35.13	Score: 32.58	Eval mean return: 33.93
# Episode 169	Average Score: 34.45	Score: 24.55	Eval mean return: 26.97
# Episode 179	Average Score: 33.90	Score: 31.50	Eval mean return: 28.34
# Episode 189	Average Score: 32.94	Score: 25.50	Eval mean return: 29.06
# Episode 199	Average Score: 32.13	Score: 28.27	Eval mean return: 27.04
# Episode 200	Average Score: 32.03	Score: 24.87
# Episode 209	Average Score: 30.98	Score: 19.86	Eval mean return: 26.49
# Episode 219	Average Score: 30.22	Score: 27.13	Eval mean return: 25.49
# Episode 229	Average Score: 29.33	Score: 23.10	Eval mean return: 21.86
# Episode 239	Average Score: 28.48	Score: 25.48	Eval mean return: 27.91
# Episode 249	Average Score: 27.62	Score: 26.40	Eval mean return: 28.52
# Episode 250	Average Score: 27.56	Score: 27.66
# Episode 259	Average Score: 27.01	Score: 24.31	Eval mean return: 20.82
# Episode 269	Average Score: 26.81	Score: 29.76	Eval mean return: 23.38
# Episode 279	Average Score: 26.62	Score: 28.24	Eval mean return: 31.67
# Episode 289	Average Score: 27.02	Score: 29.27	Eval mean return: 29.96
# Episode 299	Average Score: 27.34	Score: 30.59	Eval mean return: 27.69
# Episode 300	Average Score: 27.40	Score: 30.19
# Episode 309	Average Score: 27.90	Score: 28.00	Eval mean return: 26.46
# Episode 319	Average Score: 27.94	Score: 22.50	Eval mean return: 26.82
# Episode 329	Average Score: 28.37	Score: 29.67	Eval mean return: 30.71
# Episode 339	Average Score: 28.86	Score: 30.38	Eval mean return: 30.97
# Episode 349	Average Score: 29.41	Score: 29.32	Eval mean return: 28.74
# Episode 350	Average Score: 29.42	Score: 28.96
# Episode 359	Average Score: 29.53	Score: 35.65	Eval mean return: 31.36
# Episode 369	Average Score: 29.88	Score: 28.54	Eval mean return: 25.74
# Episode 379	Average Score: 30.26	Score: 32.89	Eval mean return: 28.30
# Episode 389	Average Score: 29.94	Score: 22.94	Eval mean return: 24.92
# Episode 399	Average Score: 29.61	Score: 26.05	Eval mean return: 28.65
# Episode 400	Average Score: 29.59	Score: 28.67
# Episode 409	Average Score: 29.75	Score: 31.05	Eval mean return: 31.24
# Episode 419	Average Score: 29.97	Score: 28.01	Eval mean return: 26.97
# Episode 429	Average Score: 29.98	Score: 30.18	Eval mean return: 31.56
# Episode 439	Average Score: 30.23	Score: 33.51	Eval mean return: 33.07
# Episode 449	Average Score: 30.54	Score: 34.20	Eval mean return: 36.05
# Episode 450	Average Score: 30.61	Score: 36.43
# Episode 459	Average Score: 31.07	Score: 29.87	Eval mean return: 30.77
# Episode 469	Average Score: 31.18	Score: 31.46	Eval mean return: 30.42
# Episode 479	Average Score: 31.00	Score: 28.74	Eval mean return: 28.55
# Episode 489	Average Score: 31.17	Score: 30.77	Eval mean return: 27.52
# Episode 499	Average Score: 31.58	Score: 34.02	Eval mean return: 30.33
# Episode 500	Average Score: 31.59	Score: 29.79
# Episode 509	Average Score: 31.53	Score: 28.28	Eval mean return: 24.85
# Episode 519	Average Score: 31.65	Score: 28.38	Eval mean return: 28.24
# Episode 529	Average Score: 31.93	Score: 34.24	Eval mean return: 28.25
# Episode 539	Average Score: 31.87	Score: 33.51	Eval mean return: 27.91
# Episode 549	Average Score: 31.71	Score: 35.39	Eval mean return: 35.04
# Episode 550	Average Score: 31.68	Score: 32.54
# Episode 559	Average Score: 31.60	Score: 34.70	Eval mean return: 29.84
# Episode 569	Average Score: 31.71	Score: 32.66	Eval mean return: 32.80
# Episode 579	Average Score: 31.87	Score: 33.12	Eval mean return: 32.38
# Episode 589	Average Score: 32.29	Score: 33.80	Eval mean return: 34.65
# Episode 599	Average Score: 32.31	Score: 32.58	Eval mean return: 29.18
# Episode 600	Average Score: 32.33	Score: 31.83
# Episode 609	Average Score: 32.27	Score: 27.85	Eval mean return: 24.67
# Episode 619	Average Score: 32.36	Score: 30.07	Eval mean return: 32.55
# Episode 629	Average Score: 32.50	Score: 32.12	Eval mean return: 28.57
# Episode 639	Average Score: 32.34	Score: 25.16	Eval mean return: 22.45
# Episode 649	Average Score: 32.04	Score: 31.20	Eval mean return: 30.87
# Episode 650	Average Score: 32.04	Score: 32.69
# Episode 659	Average Score: 31.84	Score: 30.43	Eval mean return: 30.89
# Episode 669	Average Score: 31.52	Score: 32.33	Eval mean return: 29.22
# Episode 679	Average Score: 31.50	Score: 33.16	Eval mean return: 31.63
# Episode 689	Average Score: 31.26	Score: 36.02	Eval mean return: 32.56
# Episode 699	Average Score: 31.06	Score: 24.77	Eval mean return: 20.36
# Episode 700	Average Score: 30.97	Score: 23.11
# Episode 709	Average Score: 30.66	Score: 26.65	Eval mean return: 22.97
# Episode 719	Average Score: 29.94	Score: 23.30	Eval mean return: 26.15
# Episode 729	Average Score: 29.08	Score: 25.54	Eval mean return: 20.38
# Episode 739	Average Score: 28.33	Score: 26.37	Eval mean return: 21.09
# Episode 749	Average Score: 27.90	Score: 21.96	Eval mean return: 20.81
# Episode 750	Average Score: 27.81	Score: 23.95
# Episode 759	Average Score: 26.95	Score: 21.76	Eval mean return: 19.95
# Episode 769	Average Score: 25.68	Score: 14.36	Eval mean return: 11.64
# Episode 779	Average Score: 24.39	Score: 22.74	Eval mean return: 16.74
# Episode 789	Average Score: 23.52	Score: 23.71	Eval mean return: 19.89
# Episode 799	Average Score: 22.68	Score: 21.87	Eval mean return: 21.15
# Episode 800	Average Score: 22.66	Score: 20.62
# Episode 809	Average Score: 22.27	Score: 19.90	Eval mean return: 23.72
# Episode 819	Average Score: 22.22	Score: 27.57	Eval mean return: 28.39
# Episode 829	Average Score: 22.38	Score: 27.22	Eval mean return: 28.21
# Episode 839	Average Score: 22.95	Score: 24.09	Eval mean return: 28.20
# Episode 849	Average Score: 23.01	Score: 28.19	Eval mean return: 24.19
# Episode 850	Average Score: 23.05	Score: 28.27
# Episode 859	Average Score: 23.69	Score: 31.72	Eval mean return: 28.54
# Episode 869	Average Score: 24.70	Score: 27.35	Eval mean return: 33.42
# Episode 879	Average Score: 25.13	Score: 23.75	Eval mean return: 26.93
# Episode 889	Average Score: 24.62	Score: 11.48	Eval mean return: 13.88
# Episode 899	Average Score: 23.85	Score: 14.11	Eval mean return: 13.08
# Episode 900	Average Score: 23.81	Score: 16.43
# Episode 909	Average Score: 22.55	Score: 5.210	Eval mean return: 8.93
# Episode 919	Average Score: 20.87	Score: 7.16	Eval mean return: 8.01
# Episode 929	Average Score: 18.91	Score: 6.16	Eval mean return: 5.46
# Episode 939	Average Score: 16.57	Score: 3.59	Eval mean return: 4.04
# Episode 949	Average Score: 14.27	Score: 2.62	Eval mean return: 3.06
# Episode 950	Average Score: 14.01	Score: 2.39
# Episode 959	Average Score: 11.62	Score: 1.51	Eval mean return: 0.96
# Episode 969	Average Score: 9.05	Score: 1.413	Eval mean return: 1.01
# Episode 979	Average Score: 6.87	Score: 1.55	Eval mean return: 1.40
# Episode 989	Average Score: 5.23	Score: 1.40	Eval mean return: 1.18
# Episode 999	Average Score: 3.90	Score: 0.97	Eval mean return: 1.02

# %%
data = None
if os.path.isfile(os.path.join(log_dir, pickl_name)):
    with open(os.path.join(log_dir, pickl_name), mode='rb') as pf:
        data = pickle.load(pf)
        data[seed] = (undisc_G, undisc_eval_G)
    with open(os.path.join(log_dir, pickl_name), mode='wb') as pf:
        pickle.dump(data, pf)
else:
    with open(os.path.join(log_dir, pickl_name), mode='wb') as pf:
        pickle.dump({seed:(undisc_G, undisc_eval_G)}, pf)

if data is not None:
    plot_scores(data)
# Out:
# /home/gerti/miniconda3/envs/rl/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# /home/gerti/miniconda3/envs/rl/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
